# %%
import pandas as pd

# %%
# Read CSV file to data frame and name the variables
iris = pd.read_csv("iris_data/bezdekIris.data", names=["Sepal Length", "Sepal Width", "Petal Length", "Petal Width", "class"])

# %%
iris
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Descriptive statistics for entire dataset
d = iris.describe().round(decimals=2)
d
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width
# count        150.00       150.00        150.00       150.00
# mean           5.84         3.06          3.76         1.20
# std            0.83         0.44          1.77         0.76
# min            4.30         2.00          1.00         0.10
# 25%            5.10         2.80          1.60         0.30
# 50%            5.80         3.00          4.35         1.30
# 75%            6.40         3.30          5.10         1.80
# max            7.90         4.40          6.90         2.50

# %%
# Descriptive statistics per class
class_summaries = iris.groupby(iris["class"]).describe().round(decimals=2).transpose()
class_summaries
# Out:
# class               Iris-setosa  Iris-versicolor  Iris-virginica
# Sepal Length count        50.00            50.00           50.00
#              mean          5.01             5.94            6.59
#              std           0.35             0.52            0.64
#              min           4.30             4.90            4.90
#              25%           4.80             5.60            6.22
#              50%           5.00             5.90            6.50
#              75%           5.20             6.30            6.90
#              max           5.80             7.00            7.90
# Sepal Width  count        50.00            50.00           50.00
#              mean          3.43             2.77            2.97
#              std           0.38             0.31            0.32
#              min           2.30             2.00            2.20
#              25%           3.20             2.52            2.80
#              50%           3.40             2.80            3.00
#              75%           3.68             3.00            3.18
#              max           4.40             3.40            3.80
# Petal Length count        50.00            50.00           50.00
#              mean          1.46             4.26            5.55
#              std           0.17             0.47            0.55
#              min           1.00             3.00            4.50
#              25%           1.40             4.00            5.10
#              50%           1.50             4.35            5.55
#              75%           1.58             4.60            5.88
#              max           1.90             5.10            6.90
# Petal Width  count        50.00            50.00           50.00
#              mean          0.25             1.33            2.03
#              std           0.11             0.20            0.27
#              min           0.10             1.00            1.40
#              25%           0.20             1.20            1.80
#              50%           0.20             1.30            2.00
#              75%           0.30             1.50            2.30
#              max           0.60             1.80            2.50

# %%
All = slice(None)
fig, axs = plt.subplots(4,1, sharey=True)
plt.tight_layout()
class_summaries.loc[(All, "mean"),All].transpose().plot()
for i in range(4):
    axs[i].plot(class_summaries.iloc[(i, "mean"),All].transpose())[i]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-d22f2ddbb2ff> in <module>
#       4 class_summaries.loc[(All, "mean"),All].transpose().plot()
#       5 for i in range(4):
# ----> 6     axs[i].plot(class_summaries.iloc[(i, 1)].transpose())[i]
#
# IndexError: list index out of range

# %%
iris
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# %matplotlib inline
i2 = iris.groupby(iris["class"]).describe().round(decimals=3).transpose()
i3 = i2.swaplevel(0,1)
i3.plot(marker=".", linestyle = "", rot=90)
i2
All = slice(None)
for i in ["mean", "std", "min", "25%", "50%", "75%", "max"]:
    i2.loc[(All, i),(All)].plot(marker=".", linestyle = "", rot=45, title=i.capitalize())

# %%
import seaborn as sb

# %%
sb.pairplot(iris, hue="class")

# %%
iris
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal Length  150 non-null    float64
#  1   Sepal Width   150 non-null    float64
#  2   Petal Length  150 non-null    float64
#  3   Petal Width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'Iris-setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'Iris-setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'Iris-setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'Iris-setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'Iris-setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'Iris-setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'Iris-setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'Iris-setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'Iris-setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'Iris-setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'Iris-setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'Iris-setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'Iris-setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'Iris-setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'Iris-setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'Iris-setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'Iris-setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'Iris-setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'Iris-setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'Iris-setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'Iris-setosa'],
#        [4.8, 3.4, 1.9, 0.2, 'Iris-setosa'],
#        [5.0, 3.0, 1.6, 0.2, 'Iris-setosa'],
#        [5.0, 3.4, 1.6, 0.4, 'Iris-setosa'],
#        [5.2, 3.5, 1.5, 0.2, 'Iris-setosa'],
#        [5.2, 3.4, 1.4, 0.2, 'Iris-setosa'],
#        [4.7, 3.2, 1.6, 0.2, 'Iris-setosa'],
#        [4.8, 3.1, 1.6, 0.2, 'Iris-setosa'],
#        [5.4, 3.4, 1.5, 0.4, 'Iris-setosa'],
#        [5.2, 4.1, 1.5, 0.1, 'Iris-setosa'],
#        [5.5, 4.2, 1.4, 0.2, 'Iris-setosa'],
#        [4.9, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5.0, 3.2, 1.2, 0.2, 'Iris-setosa'],
#        [5.5, 3.5, 1.3, 0.2, 'Iris-setosa'],
#        [4.9, 3.6, 1.4, 0.1, 'Iris-setosa'],
#        [4.4, 3.0, 1.3, 0.2, 'Iris-setosa'],
#        [5.1, 3.4, 1.5, 0.2, 'Iris-setosa'],
#        [5.0, 3.5, 1.3, 0.3, 'Iris-setosa'],
#        [4.5, 2.3, 1.3, 0.3, 'Iris-setosa'],
#        [4.4, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [5.0, 3.5, 1.6, 0.6, 'Iris-setosa'],
#        [5.1, 3.8, 1.9, 0.4, 'Iris-setosa'],
#        [4.8, 3.0, 1.4, 0.3, 'Iris-setosa'],
#        [5.1, 3.8, 1.6, 0.2, 'Iris-setosa'],
#        [4.6, 3.2, 1.4, 0.2, 'Iris-setosa'],
#        [5.3, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [5.0, 3.3, 1.4, 0.2, 'Iris-setosa'],
#        [7.0, 3.2, 4.7, 1.4, 'Iris-versicolor'],
#        [6.4, 3.2, 4.5, 1.5, 'Iris-versicolor'],
#        [6.9, 3.1, 4.9, 1.5, 'Iris-versicolor'],
#        [5.5, 2.3, 4.0, 1.3, 'Iris-versicolor'],
#        [6.5, 2.8, 4.6, 1.5, 'Iris-versicolor'],
#        [5.7, 2.8, 4.5, 1.3, 'Iris-versicolor'],
#        [6.3, 3.3, 4.7, 1.6, 'Iris-versicolor'],
#        [4.9, 2.4, 3.3, 1.0, 'Iris-versicolor'],
#        [6.6, 2.9, 4.6, 1.3, 'Iris-versicolor'],
#        [5.2, 2.7, 3.9, 1.4, 'Iris-versicolor'],
#        [5.0, 2.0, 3.5, 1.0, 'Iris-versicolor'],
#        [5.9, 3.0, 4.2, 1.5, 'Iris-versicolor'],
#        [6.0, 2.2, 4.0, 1.0, 'Iris-versicolor'],
#        [6.1, 2.9, 4.7, 1.4, 'Iris-versicolor'],
#        [5.6, 2.9, 3.6, 1.3, 'Iris-versicolor'],
#        [6.7, 3.1, 4.4, 1.4, 'Iris-versicolor'],
#        [5.6, 3.0, 4.5, 1.5, 'Iris-versicolor'],
#        [5.8, 2.7, 4.1, 1.0, 'Iris-versicolor'],
#        [6.2, 2.2, 4.5, 1.5, 'Iris-versicolor'],
#        [5.6, 2.5, 3.9, 1.1, 'Iris-versicolor'],
#        [5.9, 3.2, 4.8, 1.8, 'Iris-versicolor'],
#        [6.1, 2.8, 4.0, 1.3, 'Iris-versicolor'],
#        [6.3, 2.5, 4.9, 1.5, 'Iris-versicolor'],
#        [6.1, 2.8, 4.7, 1.2, 'Iris-versicolor'],
#        [6.4, 2.9, 4.3, 1.3, 'Iris-versicolor'],
#        [6.6, 3.0, 4.4, 1.4, 'Iris-versicolor'],
#        [6.8, 2.8, 4.8, 1.4, 'Iris-versicolor'],
#        [6.7, 3.0, 5.0, 1.7, 'Iris-versicolor'],
#        [6.0, 2.9, 4.5, 1.5, 'Iris-versicolor'],
#        [5.7, 2.6, 3.5, 1.0, 'Iris-versicolor'],
#        [5.5, 2.4, 3.8, 1.1, 'Iris-versicolor'],
#        [5.5, 2.4, 3.7, 1.0, 'Iris-versicolor'],
#        [5.8, 2.7, 3.9, 1.2, 'Iris-versicolor'],
#        [6.0, 2.7, 5.1, 1.6, 'Iris-versicolor'],
#        [5.4, 3.0, 4.5, 1.5, 'Iris-versicolor'],
#        [6.0, 3.4, 4.5, 1.6, 'Iris-versicolor'],
#        [6.7, 3.1, 4.7, 1.5, 'Iris-versicolor'],
#        [6.3, 2.3, 4.4, 1.3, 'Iris-versicolor'],
#        [5.6, 3.0, 4.1, 1.3, 'Iris-versicolor'],
#        [5.5, 2.5, 4.0, 1.3, 'Iris-versicolor'],
#        [5.5, 2.6, 4.4, 1.2, 'Iris-versicolor'],
#        [6.1, 3.0, 4.6, 1.4, 'Iris-versicolor'],
#        [5.8, 2.6, 4.0, 1.2, 'Iris-versicolor'],
#        [5.0, 2.3, 3.3, 1.0, 'Iris-versicolor'],
#        [5.6, 2.7, 4.2, 1.3, 'Iris-versicolor'],
#        [5.7, 3.0, 4.2, 1.2, 'Iris-versicolor'],
#        [5.7, 2.9, 4.2, 1.3, 'Iris-versicolor'],
#        [6.2, 2.9, 4.3, 1.3, 'Iris-versicolor'],
#        [5.1, 2.5, 3.0, 1.1, 'Iris-versicolor'],
#        [5.7, 2.8, 4.1, 1.3, 'Iris-versicolor'],
#        [6.3, 3.3, 6.0, 2.5, 'Iris-virginica'],
#        [5.8, 2.7, 5.1, 1.9, 'Iris-virginica'],
#        [7.1, 3.0, 5.9, 2.1, 'Iris-virginica'],
#        [6.3, 2.9, 5.6, 1.8, 'Iris-virginica'],
#        [6.5, 3.0, 5.8, 2.2, 'Iris-virginica'],
#        [7.6, 3.0, 6.6, 2.1, 'Iris-virginica'],
#        [4.9, 2.5, 4.5, 1.7, 'Iris-virginica'],
#        [7.3, 2.9, 6.3, 1.8, 'Iris-virginica'],
#        [6.7, 2.5, 5.8, 1.8, 'Iris-virginica'],
#        [7.2, 3.6, 6.1, 2.5, 'Iris-virginica'],
#        [6.5, 3.2, 5.1, 2.0, 'Iris-virginica'],
#        [6.4, 2.7, 5.3, 1.9, 'Iris-virginica'],
#        [6.8, 3.0, 5.5, 2.1, 'Iris-virginica'],
#        [5.7, 2.5, 5.0, 2.0, 'Iris-virginica'],
#        [5.8, 2.8, 5.1, 2.4, 'Iris-virginica'],
#        [6.4, 3.2, 5.3, 2.3, 'Iris-virginica'],
#        [6.5, 3.0, 5.5, 1.8, 'Iris-virginica'],
#        [7.7, 3.8, 6.7, 2.2, 'Iris-virginica'],
#        [7.7, 2.6, 6.9, 2.3, 'Iris-virginica'],
#        [6.0, 2.2, 5.0, 1.5, 'Iris-virginica'],
#        [6.9, 3.2, 5.7, 2.3, 'Iris-virginica'],
#        [5.6, 2.8, 4.9, 2.0, 'Iris-virginica'],
#        [7.7, 2.8, 6.7, 2.0, 'Iris-virginica'],
#        [6.3, 2.7, 4.9, 1.8, 'Iris-virginica'],
#        [6.7, 3.3, 5.7, 2.1, 'Iris-virginica'],
#        [7.2, 3.2, 6.0, 1.8, 'Iris-virginica'],
#        [6.2, 2.8, 4.8, 1.8, 'Iris-virginica'],
#        [6.1, 3.0, 4.9, 1.8, 'Iris-virginica'],
#        [6.4, 2.8, 5.6, 2.1, 'Iris-virginica'],
#        [7.2, 3.0, 5.8, 1.6, 'Iris-virginica'],
#        [7.4, 2.8, 6.1, 1.9, 'Iris-virginica'],
#        [7.9, 3.8, 6.4, 2.0, 'Iris-virginica'],
#        [6.4, 2.8, 5.6, 2.2, 'Iris-virginica'],
#        [6.3, 2.8, 5.1, 1.5, 'Iris-virginica'],
#        [6.1, 2.6, 5.6, 1.4, 'Iris-virginica'],
#        [7.7, 3.0, 6.1, 2.3, 'Iris-virginica'],
#        [6.3, 3.4, 5.6, 2.4, 'Iris-virginica'],
#        [6.4, 3.1, 5.5, 1.8, 'Iris-virginica'],
#        [6.0, 3.0, 4.8, 1.8, 'Iris-virginica'],
#        [6.9, 3.1, 5.4, 2.1, 'Iris-virginica'],
#        [6.7, 3.1, 5.6, 2.4, 'Iris-virginica'],
#        [6.9, 3.1, 5.1, 2.3, 'Iris-virginica'],
#        [5.8, 2.7, 5.1, 1.9, 'Iris-virginica'],
#        [6.8, 3.2, 5.9, 2.3, 'Iris-virginica'],
#        [6.7, 3.3, 5.7, 2.5, 'Iris-virginica'],
#        [6.7, 3.0, 5.2, 2.3, 'Iris-virginica'],
#        [6.3, 2.5, 5.0, 1.9, 'Iris-virginica'],
#        [6.5, 3.0, 5.2, 2.0, 'Iris-virginica'],
#        [6.2, 3.4, 5.4, 2.3, 'Iris-virginica'],
#        [5.9, 3.0, 5.1, 1.8, 'Iris-virginica']], dtype=object)

# %%
iris.columns
# Out:
# Index(['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width', 'class'], dtype='object')

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
iris.sort_values(["Sepal Width", "Sepal Length"], ascending = [False, True])
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width            class
# 15            5.7          4.4           1.5          0.4      Iris-setosa
# 33            5.5          4.2           1.4          0.2      Iris-setosa
# 32            5.2          4.1           1.5          0.1      Iris-setosa
# 14            5.8          4.0           1.2          0.2      Iris-setosa
# 5             5.4          3.9           1.7          0.4      Iris-setosa
# ..            ...          ...           ...          ...              ...
# 87            6.3          2.3           4.4          1.3  Iris-versicolor
# 62            6.0          2.2           4.0          1.0  Iris-versicolor
# 119           6.0          2.2           5.0          1.5   Iris-virginica
# 68            6.2          2.2           4.5          1.5  Iris-versicolor
# 60            5.0          2.0           3.5          1.0  Iris-versicolor
#
# [150 rows x 5 columns]

# %%
iris["class"]
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: class, Length: 150, dtype: object

# %%
iris[["class", "Sepal Width", "Sepal Length"]]
# Out:
#               class  Sepal Width  Sepal Length
# 0       Iris-setosa          3.5           5.1
# 1       Iris-setosa          3.0           4.9
# 2       Iris-setosa          3.2           4.7
# 3       Iris-setosa          3.1           4.6
# 4       Iris-setosa          3.6           5.0
# ..              ...          ...           ...
# 145  Iris-virginica          3.0           6.7
# 146  Iris-virginica          2.5           6.3
# 147  Iris-virginica          3.0           6.5
# 148  Iris-virginica          3.4           6.2
# 149  Iris-virginica          3.0           5.9
#
# [150 rows x 3 columns]

# %%
iris[ iris["Sepal Width"] > 4 ]
# Out:
#     Sepal Length  Sepal Width  Petal Length  Petal Width        class
# 15           5.7          4.4           1.5          0.4  Iris-setosa
# 32           5.2          4.1           1.5          0.1  Iris-setosa
# 33           5.5          4.2           1.4          0.2  Iris-setosa

# %%
iris["class"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
se = iris["class"] == "Iris-setosa"
ve = iris["class"] == "Iris-versicolor"
vi = iris["class"] == "Iris-virginica"
iris[se]
# Out:
#     Sepal Length  Sepal Width  Petal Length  Petal Width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# 12           4.8          3.0           1.4          0.1  Iris-setosa
# 13           4.3          3.0           1.1          0.1  Iris-setosa
# 14           5.8          4.0           1.2          0.2  Iris-setosa
# 15           5.7          4.4           1.5          0.4  Iris-setosa
# 16           5.4          3.9           1.3          0.4  Iris-setosa
# 17           5.1          3.5           1.4          0.3  Iris-setosa
# 18           5.7          3.8           1.7          0.3  Iris-setosa
# 19           5.1          3.8           1.5          0.3  Iris-setosa
# 20           5.4          3.4           1.7          0.2  Iris-setosa
# 21           5.1          3.7           1.5          0.4  Iris-setosa
# 22           4.6          3.6           1.0          0.2  Iris-setosa
# 23           5.1          3.3           1.7          0.5  Iris-setosa
# 24           4.8          3.4           1.9          0.2  Iris-setosa
# 25           5.0          3.0           1.6          0.2  Iris-setosa
# 26           5.0          3.4           1.6          0.4  Iris-setosa
# 27           5.2          3.5           1.5          0.2  Iris-setosa
# 28           5.2          3.4           1.4          0.2  Iris-setosa
# 29           4.7          3.2           1.6          0.2  Iris-setosa
# 30           4.8          3.1           1.6          0.2  Iris-setosa
# 31           5.4          3.4           1.5          0.4  Iris-setosa
# 32           5.2          4.1           1.5          0.1  Iris-setosa
# 33           5.5          4.2           1.4          0.2  Iris-setosa
# 34           4.9          3.1           1.5          0.2  Iris-setosa
# 35           5.0          3.2           1.2          0.2  Iris-setosa
# 36           5.5          3.5           1.3          0.2  Iris-setosa
# 37           4.9          3.6           1.4          0.1  Iris-setosa
# 38           4.4          3.0           1.3          0.2  Iris-setosa
# 39           5.1          3.4           1.5          0.2  Iris-setosa
# 40           5.0          3.5           1.3          0.3  Iris-setosa
# 41           4.5          2.3           1.3          0.3  Iris-setosa
# 42           4.4          3.2           1.3          0.2  Iris-setosa
# 43           5.0          3.5           1.6          0.6  Iris-setosa
# 44           5.1          3.8           1.9          0.4  Iris-setosa
# 45           4.8          3.0           1.4          0.3  Iris-setosa
# 46           5.1          3.8           1.6          0.2  Iris-setosa
# 47           4.6          3.2           1.4          0.2  Iris-setosa
# 48           5.3          3.7           1.5          0.2  Iris-setosa
# 49           5.0          3.3           1.4          0.2  Iris-setosa

# %%
iris[iris["class"].isin(["Iris-setosa", "Iris-versicolor"])]
# Out:
#     Sepal Length  Sepal Width  Petal Length  Petal Width            class
# 0            5.1          3.5           1.4          0.2      Iris-setosa
# 1            4.9          3.0           1.4          0.2      Iris-setosa
# 2            4.7          3.2           1.3          0.2      Iris-setosa
# 3            4.6          3.1           1.5          0.2      Iris-setosa
# 4            5.0          3.6           1.4          0.2      Iris-setosa
# ..           ...          ...           ...          ...              ...
# 95           5.7          3.0           4.2          1.2  Iris-versicolor
# 96           5.7          2.9           4.2          1.3  Iris-versicolor
# 97           6.2          2.9           4.3          1.3  Iris-versicolor
# 98           5.1          2.5           3.0          1.1  Iris-versicolor
# 99           5.7          2.8           4.1          1.3  Iris-versicolor
#
# [100 rows x 5 columns]

# %%
iris["Sepal Area"] = iris["Sepal Length"] * iris["Sepal Width"]
iris["Petal Area"] = iris["Petal Length"] * iris["Petal Width"]
iris.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width        class  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    Sepal Area  Petal Area
# 0       17.85        0.28
# 1       14.70        0.28
# 2       15.04        0.26
# 3       14.26        0.30
# 4       18.00        0.28

# %%
iris_area = iris[iris["class"].isin(["Iris-virginica", "Iris-versicolor"])][["class", "Sepal Area", "Petal Area"]]

# %%
sb.pairplot(iris_area, hue="class")

# %%
iris_area["Sepal Area"].mean()
# Out:
# 18.105399999999996

# %%
iris_area[iris_area["class"] == "Iris-versicolor"]["Sepal Area"].mean()
# Out:
# 16.526200000000003

# %%
iris_area[iris_area["class"] == "Iris-versicolor"].mean()
# Out:
# Sepal Area    16.5262
# Petal Area     5.7204
# dtype: float64

# %%
iris_area.mean()
# Out:
# Sepal Area    18.1054
# Petal Area     8.5083
# dtype: float64

# %%
iris.mean()
# Out:
# Sepal Length     5.843333
# Sepal Width      3.057333
# Petal Length     3.758000
# Petal Width      1.199333
# Sepal Area      17.822867
# Petal Area       5.794067
# dtype: float64

# %%
iris[iris["class"] == "Iris-versicolor"].mean()
# Out:
# Sepal Length     5.9360
# Sepal Width      2.7700
# Petal Length     4.2600
# Petal Width      1.3260
# Sepal Area      16.5262
# Petal Area       5.7204
# dtype: float64

# %%
iris["Sepal Length"].agg(lambda x: x.quantile(0.3))
# Out:
# 5.27

# %%
iris[["Sepal Length", "Sepal Width"]].agg([lambda x: x.quantile(0.3), lambda y: y.quantile(0.4)])
# Out:
#           Sepal Length  Sepal Width
# <lambda>          5.27          2.8
# <lambda>          5.60          3.0

# %%
iris.groupby("class").mean()
# Out:
#                  Sepal Length  Sepal Width  Petal Length  Petal Width  \
# class
# Iris-setosa             5.006        3.428         1.462        0.246
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026
#
#                  Sepal Area  Petal Area
# class
# Iris-setosa         17.2578      0.3656
# Iris-versicolor     16.5262      5.7204
# Iris-virginica      19.6846     11.2962

# %%
iris.groupby("class").describe()
# Out:
#                 Sepal Length                                              \
#                        count   mean       std  min    25%  50%  75%  max
# class
# Iris-setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#                 Sepal Width         ... Sepal Area        Petal Area           \
#                       count   mean  ...        75%    max      count     mean
# class                               ...
# Iris-setosa            50.0  3.428  ...    19.1550  25.08       50.0   0.3656
# Iris-versicolor        50.0  2.770  ...    18.4950  22.40       50.0   5.7204
# Iris-virginica         50.0  2.974  ...    21.4125  30.02       50.0  11.2962
#
#
#                       std   min     25%     50%    75%    max
# class
# Iris-setosa      0.181155  0.11  0.2800   0.300   0.42   0.96
# Iris-versicolor  1.368403  3.30  4.8600   5.615   6.75   8.64
# Iris-virginica   2.157412  7.50  9.7175  11.445  12.79  15.87
#
# [3 rows x 48 columns]

# %%
import numpy as np
iris.groupby("class").agg([np.mean, np.std, min, max])
# Out:
#                 Sepal Length                     Sepal Width                 \
#                         mean       std  min  max        mean       std  min
# class
# Iris-setosa            5.006  0.352490  4.3  5.8       3.428  0.379064  2.3
# Iris-versicolor        5.936  0.516171  4.9  7.0       2.770  0.313798  2.0
# Iris-virginica         6.588  0.635880  4.9  7.9       2.974  0.322497  2.2
#
#                      Petal Length            ... Petal Width      Sepal Area  \
#                  max         mean       std  ...         min  max       mean
# class                                        ...
# Iris-setosa      4.4        1.462  0.173664  ...         0.1  0.6    17.2578
# Iris-versicolor  3.4        4.260  0.469911  ...         1.0  1.8    16.5262
# Iris-virginica   3.8        5.552  0.551895  ...         1.4  2.5    19.6846
#
#                                         Petal Area
#                       std    min    max       mean       std   min    max
# class
# Iris-setosa      2.933775  10.35  25.08     0.3656  0.181155  0.11   0.96
# Iris-versicolor  2.866882  10.00  22.40     5.7204  1.368403  3.30   8.64
# Iris-virginica   3.458783  12.25  30.02    11.2962  2.157412  7.50  15.87
#
# [3 rows x 24 columns]

# %%
iris.pivot_table(values="Sepal Area", index="class",  margins=True)
# Out:
#                  Sepal Area
# class
# Iris-setosa       17.257800
# Iris-versicolor   16.526200
# Iris-virginica    19.684600
# All               17.822867

# %%
iris[iris["class"] == "Iris-versicolor"].mean()
# Out:
# Sepal Length     5.9360
# Sepal Width      2.7700
# Petal Length     4.2600
# Petal Width      1.3260
# Sepal Area      16.5262
# Petal Area       5.7204
# dtype: float64

# %%
iris[iris["class"] == "Iris-versicolor"].describe()
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width  Sepal Area  \
# count     50.000000    50.000000     50.000000    50.000000   50.000000
# mean       5.936000     2.770000      4.260000     1.326000   16.526200
# std        0.516171     0.313798      0.469911     0.197753    2.866882
# min        4.900000     2.000000      3.000000     1.000000   10.000000
# 25%        5.600000     2.525000      4.000000     1.200000   14.347500
# 50%        5.900000     2.800000      4.350000     1.300000   16.385000
# 75%        6.300000     3.000000      4.600000     1.500000   18.495000
# max        7.000000     3.400000      5.100000     1.800000   22.400000
#
#        Petal Area
# count   50.000000
# mean     5.720400
# std      1.368403
# min      3.300000
# 25%      4.860000
# 50%      5.615000
# 75%      6.750000
# max      8.640000

# %%
iris_ind = iris.set_index("class")

# %%
iris_ind.loc[["Iris-setosa"]].describe()
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width  Sepal Area  \
# count      50.00000    50.000000     50.000000    50.000000   50.000000
# mean        5.00600     3.428000      1.462000     0.246000   17.257800
# std         0.35249     0.379064      0.173664     0.105386    2.933775
# min         4.30000     2.300000      1.000000     0.100000   10.350000
# 25%         4.80000     3.200000      1.400000     0.200000   15.040000
# 50%         5.00000     3.400000      1.500000     0.200000   17.170000
# 75%         5.20000     3.675000      1.575000     0.300000   19.155000
# max         5.80000     4.400000      1.900000     0.600000   25.080000
#
#        Petal Area
# count   50.000000
# mean     0.365600
# std      0.181155
# min      0.110000
# 25%      0.280000
# 50%      0.300000
# 75%      0.420000
# max      0.960000

# %%
iris_ind.loc[:, "Sepal Length":"Petal Width"].describe()
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_ind.loc["Iris-setosa":"Iris-versicolor", "Sepal Length":"Petal Width"].describe()
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width
# count    100.000000   100.000000    100.000000   100.000000
# mean       5.471000     3.099000      2.861000     0.786000
# std        0.641698     0.478739      1.449549     0.565153
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.000000     2.800000      1.500000     0.200000
# 50%        5.400000     3.050000      2.450000     0.800000
# 75%        5.900000     3.400000      4.325000     1.300000
# max        7.000000     4.400000      5.100000     1.800000

# %%
# Bin Sepal width and show mean sepal length for each sepal width category, broken down by class
iris["Sepal Width Bins"] = pd.cut(iris["Sepal Width"],6)
iris.pivot_table("Sepal Length", index="class", columns="Sepal Width Bins")
# Out:
# Sepal Width Bins  (1.998, 2.4]  (2.4, 2.8]  (2.8, 3.2]  (3.2, 3.6]  \
# class
# Iris-setosa           4.500000         NaN    4.700000    5.040000
# Iris-versicolor       5.544444    5.822222    6.180952    6.150000
# Iris-virginica        6.000000    6.305556    6.734783    6.566667
#
# Sepal Width Bins  (3.6, 4.0]  (4.0, 4.4]
# class
# Iris-setosa             5.34    5.466667
# Iris-versicolor          NaN         NaN
# Iris-virginica          7.80         NaN

# %%
import matplotlib.pyplot as plt
iris["Sepal Length"].hist(bins=20)
plt.show()
iris["Sepal Width"].hist()
plt.show()
iris.plot(kind="bar")
plt.show()

# %%
iris.plot(x="Sepal Length", y="Sepal Width", c=iris["class"].map({"Iris-setosa": "red", "Iris-virginica":"green", "Iris-versicolor":"blue"}), kind="scatter")
plt.legend(["Iris-setosa", "Iris-virginica", "Iris-versicolor"])
plt.show()
iris.plot(x="Petal Length", y="Petal Width", c=iris["class"].map({"Iris-setosa": "red", "Iris-virginica":"green", "Iris-versicolor":"blue"}), kind="scatter")
plt.legend(["Iris-setosa", "Iris-virginica", "Iris-versicolor"])
plt.show()

# %%
import seaborn as sns
sns.set()
for variety in ["Iris-setosa", "Iris-versicolor", "Iris-virginica"]:
    iris[iris["class"]==variety]["Sepal Width"].hist(alpha=0.5)
    plt.show()

# %%
iris.isna().any()
# Out:
# Sepal Length        False
# Sepal Width         False
# Petal Length        False
# Petal Width         False
# class               False
# Sepal Area          False
# Petal Area          False
# Sepal Width Bins    False
# dtype: bool

# %%
iris[["Sepal Width", "Sepal Length", "Petal Width", "Petal Length"]].hist()
# Out:
# array([[<AxesSubplot:title={'center':'Sepal Width'}>,
#         <AxesSubplot:title={'center':'Sepal Length'}>],
#        [<AxesSubplot:title={'center':'Petal Width'}>,
#         <AxesSubplot:title={'center':'Petal Length'}>]], dtype=object)

# %%
iris.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Sepal Length'}>,
#         <AxesSubplot:title={'center':'Sepal Width'}>],
#        [<AxesSubplot:title={'center':'Petal Length'}>,
#         <AxesSubplot:title={'center':'Petal Width'}>],
#        [<AxesSubplot:title={'center':'Sepal Area'}>,
#         <AxesSubplot:title={'center':'Petal Area'}>]], dtype=object)

# %%
iris.groupby("class").hist()
# Out:
# class
# Iris-setosa        [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# Iris-versicolor    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# Iris-virginica     [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# dtype: object

# %%
fig, ax = plt.subplots(4,4, sharey=True)
plt.tight_layout()

# %%
print(ax)
# Out:
# [[<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>]]

# %%
# Make the graph 15 inches by 10 inches
#plt.figure(figsize=(15,10), facecolor='white')
features = ["Sepal Length", "Sepal Width", "Petal Length", "Petal Width"]
varieties = ["I. setosa", "I. versicolor", "I. virginica"]

fig, axes = plt.subplots(3,4, sharey=True, figsize=(15,10))

# plot numbering starts at 1, not 0
plot_number = 1
for variety, selection in iris.groupby("class"):
    # Inside of an image that's a 3X4 grid, put this
    # graph in the in the plot_number slot.
    for feature in features:
        ax = plt.subplot(3, 4, plot_number)
        selection.hist(feature, ax=ax, label=variety, legend=False, bins=20)
        ax.set_title(variety)
        # Go to the next plot for the next loop
        plot_number += 1
        
for axis, feature in zip(ax[0], features):
    axis.set_title(feature)

for axis, variety in zip(ax[:,0], varieties):
    axis.set_ylabel(variety, rotation=0, size='large')
    
plt.tight_layout()
#REF http://jonathansoma.com/lede/data-studio/classes/small-multiples/long-explanation-of-using-plt-subplots-to-create-small-multiples/
#REF for row and col labels" https://stackoverflow.com/a/25814386
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-c1b1418349f6> in <module>
#      18         plot_number += 1
#      19
# ---> 20 for axis, feature in zip(ax[0], features):
#      21     axis.set_title(feature)
#      22
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
#Check distribution and look for outliers

# %%
import matplotlib
matplotlib.style.use("ggplot")
f = iris.boxplot(column='Sepal Length', by='class', figsize=(9,9)).get_figure() # save figure to variable
#f.set_size_inches([5,5]) # set figure size
f.savefig("delme.png") # save figure (, dpi=100)
iris.boxplot(column='Sepal Width', by='class', figsize=(9,9))
iris.boxplot(column='Petal Length', by='class', figsize=(9,9))
iris.boxplot(column='Petal Width', by='class', figsize=(9,9))
iris.boxplot(column='Sepal Area', by='class', figsize=(9,9))
iris.boxplot(column='Petal Area', by='class', figsize=(9,9))

# %%
varieties = iris["class"].unique()

# %%
fig, ax = plt.subplots()
for variety in iris["class"].unique():
    vdf = iris[iris["class"] == variety]
    chars = 
    ax.bar(variety, chars)
#    for characteristic in ["Sepal Length", "Sepal Width", "Petal Length", "Petal Width"]:
#        ax.bar(variety, vdf[characteristic].mean(),
#        yerr = vdf[characteristic].std())
plt.show()

# %%
iris[["Sepal Length", "Sepal Width", "Petal Length", "Petal Width"]]

# %%
#Isolate unclassifiable

# %%
# %matplotlib
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection='3d')
colours = iris["class"].map({'Iris-setosa':"red", 'Iris-versicolor':"Blue", 'Iris-virginica':"Orange"})
ax.scatter(iris["Petal Width"], iris["Petal Area"], iris["Sepal Area"], c=colours)
ax.set_title('3d Scatter plot')
ax.set_xlabel("Petal Width")
ax.set_ylabel("Petal Length")
ax.set_zlabel("Sepal Area")
ax.legend()
plt.show()

# %%
iris["class"].map({'Iris-setosa':"red", 'Iris-versicolor':"Blue", 'Iris-virginica':"Orange"})

# %%
import seaborn as sns
sns.barplot(x="Sepal Width", y="Sepal Length", hue="class", data=iris)

# %%
sns.relplot(x="Sepal Width", y="Sepal Length", data=iris, hue="class")

# %%
sns.set() # Seaborn style for matplotlib
_ = plt.hist(iris["Sepal Width"])
#HISTOGRAM NUMBER OF BINS SQRT RULE

# %%
### Plot quartiles on ECDF ###

# Plot the ECDF
_ = plt.plot(x_vers, y_vers, '.')
_ = plt.xlabel('petal length (cm)')
_ = plt.ylabel('ECDF')

# Overlay percentiles as red diamonds.
_ = plt.plot(ptiles_vers, percentiles/100, marker='D', color='red',
         linestyle="none")

# Show the plot
plt.show()
